# %%
import os
os.system("cls")

import numpy as np
import pandas as pd

plotDataFrame = pd.DataFrame(np.random.randn(10,5), index = pd.date_range('11/1/2025', periods = 10), columns = list('PQRST'))

print("\n", plotDataFrame, end="\n")
# Out:
#                     P         Q         R         S         T
# 2025-11-01  0.577761  0.163722 -0.189210 -0.215608 -0.238008
# 2025-11-02  1.805363  1.181342 -1.680848 -0.366564  0.925712
# 2025-11-03 -0.224632  1.355490  0.994381 -0.150031  1.177344
# 2025-11-04 -1.143334 -1.727605 -1.036557 -0.635116  2.204865
# 2025-11-05 -0.275995 -0.809676  0.251667  0.029655  1.002428
# 2025-11-06 -2.079970  0.204050 -1.928440  0.938979  0.167124
# 2025-11-07  0.862098  1.498854 -2.142030 -0.890856 -1.327954
# 2025-11-08 -0.130148  1.247317 -2.468153 -0.805966 -0.881780
# 2025-11-09 -0.332987 -0.527164  0.426333  2.192082 -1.358993
# 2025-11-10 -0.958739 -0.029421 -1.154498 -0.100016 -0.081790

# %%
plotDataFrame.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
import os
os.system("cls")

import numpy as np
import pandas as pd

plotDataFrame = pd.DataFrame(np.random.randn(10,5), index = pd.date_range('11/1/2025', periods = 10), columns = list('PQRST'))

print("\n", plotDataFrame, end="\n")
# Out:
#                     P         Q         R         S         T
# 2025-11-01  1.570298 -0.143469  0.293688  1.089934 -0.936602
# 2025-11-02  0.102831  0.265691 -1.126314  0.116966 -1.428349
# 2025-11-03  2.829155  1.205364  1.457318  1.423674 -1.648982
# 2025-11-04  0.215822  0.894339 -2.226394 -1.844561 -0.141398
# 2025-11-05  1.909562 -0.155033  0.659119  1.729945 -1.391758
# 2025-11-06  0.704888 -0.002100  0.119703 -3.205873  0.923008
# 2025-11-07 -0.473847  1.085594 -0.157879  0.756926 -0.332300
# 2025-11-08  0.352308 -0.684490 -0.324171  1.500778  1.695230
# 2025-11-09 -0.515416 -1.263656  0.281246 -1.099382 -0.487723
# 2025-11-10 -0.216211  0.651923  2.247242  1.044722  1.138203

# %%
plotDataFrame.plot()
# Out:
# <Axes: >

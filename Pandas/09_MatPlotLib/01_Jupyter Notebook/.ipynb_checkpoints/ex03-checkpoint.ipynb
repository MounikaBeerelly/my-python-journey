# %%
import os
os.system("cls")

import numpy as np
import pandas as pd

plotDataFrame = pd.DataFrame(np.random.randn(10,5), index = pd.date_range('11/1/2025', periods = 10), columns = list('PQRST'))

print("\n", plotDataFrame, end="\n")
# Out:
#                     P         Q         R         S         T
# 2025-11-01  0.357757  0.424727  0.768495 -0.998742  0.116398
# 2025-11-02  0.164277  0.984638 -0.882672  0.063144 -0.592347
# 2025-11-03 -0.005938  0.424166  0.909946  0.376628  0.764831
# 2025-11-04  0.202175 -2.523885 -2.950608 -1.804272 -1.001540
# 2025-11-05  0.858407 -1.150273  0.826324  1.434226 -1.376325
# 2025-11-06 -0.204619 -0.025788 -1.778589 -2.220858  0.588320
# 2025-11-07 -0.282375 -0.796954 -1.041479  0.046046 -0.160006
# 2025-11-08 -0.869994 -1.606889 -1.921540 -0.992376 -0.729808
# 2025-11-09 -2.364917  0.226587 -1.485671  0.065755  0.651019
# 2025-11-10 -0.692151  1.434567  0.315819 -0.115730 -0.556166

# %%
plotDataFrame.plot.box()
# Out:
# <Axes: >

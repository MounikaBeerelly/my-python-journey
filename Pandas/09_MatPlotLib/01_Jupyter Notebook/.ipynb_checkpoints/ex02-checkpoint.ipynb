# %%
import os
os.system("cls")

import numpy as np
import pandas as pd

plotDataFrame = pd.DataFrame(np.random.randn(10,5), index = pd.date_range('11/1/2025', periods = 10), columns = list('PQRST'))

print("\n", plotDataFrame, end="\n")
# Out:
#                     P         Q         R         S         T
# 2025-11-01 -0.402434 -0.032757 -0.645290  0.098821 -1.154243
# 2025-11-02  0.056646  0.256750 -0.128833  0.305920  0.003073
# 2025-11-03  1.333465  1.292933  0.923838  0.549691  0.374254
# 2025-11-04  0.989682  0.133715  1.176461 -1.503820  0.163721
# 2025-11-05  0.676304  0.346365  0.227995  0.392232 -0.514602
# 2025-11-06  1.539600  0.511488 -0.115641  1.444943 -2.277591
# 2025-11-07 -1.418654  0.156051 -0.902793  0.230958 -0.266902
# 2025-11-08 -0.903317  0.683997 -1.833732 -0.547372 -0.044475
# 2025-11-09 -0.893157 -0.814786 -0.245783  1.554089 -1.469340
# 2025-11-10 -0.218242  0.703022 -0.112526 -0.196647 -1.411063

# %%
plotDataFrame.plot.bar()
# Out:
# <Axes: >
